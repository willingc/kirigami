# %%
import pandas as pd
# Out:
# /var/folders/7l/wcc2bqsd5pd48ljr1qm63nym0000gn/T/ipykernel_2038/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_json('../categories.json')

# %%
df
# Out:
#      color                                      custom_fields  \
# 0   FAC731  {'create_as_post_voting_default': None, 'disab...
# 1   006B94  {'create_as_post_voting_default': None, 'disab...
# 2   3AB54A  {'create_as_post_voting_default': None, 'disab...
# 3   E45735  {'create_as_post_voting_default': None, 'disab...
# 4   0088CC  {'create_as_post_voting_default': None, 'disab...
# 5   25AAE2  {'create_as_post_voting_default': None, 'disab...
# 6   0088CC  {'create_as_post_voting_default': None, 'disab...
# 7   F7941D  {'create_as_post_voting_default': None, 'disab...
# 8   ED207B  {'create_as_post_voting_default': None, 'disab...
# 9   12A89D  {'create_as_post_voting_default': None, 'disab...
# 10  9EB83B  {'create_as_post_voting_default': None, 'disab...
# 11  654ff0  {'create_as_post_voting_default': None, 'disab...
# 12  0088CC  {'create_as_post_voting_default': None, 'disab...
# 13  92278F  {'create_as_post_voting_default': None, 'disab...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      color                                      custom_fields  \
# 0   FAC731  {'create_as_post_voting_default': None, 'disab...
# 1   006B94  {'create_as_post_voting_default': None, 'disab...
# 2   3AB54A  {'create_as_post_voting_default': None, 'disab...
# 3   E45735  {'create_as_post_voting_default': None, 'disab...
# 4   0088CC  {'create_as_post_voting_default': None, 'disab...
# 5   25AAE2  {'create_as_post_voting_default': None, 'disab...
# 6   0088CC  {'create_as_post_voting_default': None, 'disab...
# 7   F7941D  {'create_as_post_voting_default': None, 'disab...
# 8   ED207B  {'create_as_post_voting_default': None, 'disab...
# 9   12A89D  {'create_as_post_voting_default': None, 'disab...
# 10  9EB83B  {'create_as_post_voting_default': None, 'disab...
# 11  654ff0  {'create_as_post_voting_default': None, 'disab...
# 12  0088CC  {'create_as_post_voting_default': None, 'disab...
# 13  92278F  {'create_as_post_voting_default': None, 'disab...
# ...
